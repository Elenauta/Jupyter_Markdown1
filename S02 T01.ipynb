# %% [markdown]
# # S02 T01: Jupyter Notebook i Markdown
#
# ### ⭐️ Nivell 1
#
# ##### - Exercici 1
#
#     Insta.la el programa Anaconda amb Python 3 i Jupyter Notebook.
#
#     💪🏻 fet!

# %% [markdown]
# ##### - Exercici 2

# %% [markdown]
#     Utilitzant Jupyter Notebook, executa alguns càlculs senzills, a la vegada que et familiaritzes amb el llenguatge Markdown

# %%
2+2  # sembla que no cal el 'print'
# Out:
# 4

# %%
3**2
# Out:
# 9

# %%
3%2
# Out:
# 1

# %%
n = 4
print(n + 3)
# Out:
# 7

# %%
n = 3
z = 5
z * n
# Out:
# 15

# %%
print(10 < 9)
print(10 > 9)
# Out:
# False
# True

# %%
x = 34 - 23
y = "Hello"
x = x + 1
y = y + " " + "World"          
print(x)
print(y)
# Out:
# 12
# Hello World

# %%
nota_1 = 4
nota_2 = 7
nota_mitja = int((nota_1 + nota_2) / 2)
print(nota_mitja)
# Out:
# 5

# %%
x = 2
y = "Maig"
print("avui es ", str(x), "de ", y)
# Out:
# avui es  2 de  Maig

# %%
print(str(x) + " de " + y)
# Out:
# 2 de Maig

# %% [markdown]
#     💪🏻 fet

# %% [markdown]
# ##### - Exercici 3

# %% [markdown]
#     Proba de crear títols, llistes, canviar l´estil de la lletra o afegir imatges dins del Notebook.

# %% [markdown]
# ****

# %% [markdown]
# # _Això és un títol_

# %% [markdown]
# ## I això un títol més petit, un __subtítol__

# %% [markdown]
# ### Més petit!

# %% [markdown]
# ###### I encara més petit.

# %% [markdown]
# 1. El primer títol té la lletra en _cursiva_
# 2. El segón en __negreta__   (baja, sembla que es obvi:)
# 3. Els altres dos tenen la lletra normal

# %% [markdown]
# ---

# %% [markdown]
# Llista de la __compra__:
#
# - patates
# - mongetes
# - pomes
# - peres

# %% [markdown]
# <a>http://www.google.com

# %% [markdown]
# ![2021-09-13_puigverd_IG.jpeg](attachment:2021-09-13_puigverd_IG.jpeg)

# %% [markdown]
# ![IMG_4793.JPG](attachment:IMG_4793.JPG)

# %% [markdown]
#     💪🏻 fet

# %% [markdown]
# ### ⭐️ ⭐️ Nivell 2

# %% [markdown]
# ##### - Exercici 1

# %% [markdown]
# Exporta el Notebook com a PDF i com a HTML

# %% [markdown]
#  <a>file:///Users/elenabartaaloy/Downloads/S02%20T01-2.html<a>

# %%
# pel PDF necessitaré més temps, em dona error ...

# %% [markdown]
# ### ⭐️⭐️⭐️ Nivell 3

# %% [markdown]
# ##### - Exercici 1

# %% [markdown]
# Instal.la Nbextensions al Notebook de Jupyter

# %%
# també aquest el deixo per més endavant ;)

# %% [markdown]
# ________

# %% [markdown]
# # O B J E C T I U S

# %% [markdown]
# - Crear variables
# - Operacions matemàtiques
# - Transforma amb càsting
# - Tècniques amb Strings
# - Booleans

# %% [markdown]
# # L L I U R A M E N T

# %% [markdown]
# Enviar la URL a un repositori anomenat **Jupyter_Markdown** que contingui la solució. S'ha d'entregar cada Excercici en un mateix fitxer i en un repositori. Cal adjuntar un arxiu de text amb l'enllaç al repositori Github.
